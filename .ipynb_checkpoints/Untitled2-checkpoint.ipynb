# %%
import cv2
import glob

import os  
import csv
import numpy as np
import random
import dlib
from skimage import io

emotions = ["anger", "disgust", "fear", "happy", "sad", "surprise", "neutral"]
rootpath = "/Users/scott/Downloads/Emotion"


# def listdir(path):  
#     list_dir = os.listdir(path)
#     #print((list_dir))
#     return list_dir
# label = []
# label_file = []
# list_dir = listdir(rootpath)
# a = 0
# for i in range(1,len(list_dir)):
#     path_1 = rootpath +"/"+list_dir[i]
#     list_dir_1 = listdir(path_1)
#     for j in range(0,len(list_dir_1)):
#         if list_dir_1[j]!=".DS_Store":
#             path_2 = path_1+"/"+list_dir_1[j]
#             list_dir_2 = listdir(path_2)
#             if(list_dir_2!=[]):
#                 #print(list_dir_2)
#                 a = a+1
#                 label_file.append(list_dir_2[0])
#                 with open(path_2+"/"+list_dir_2[0]) as f:
#                     content = f.readlines()
#                     #print(content[0].rstrip('.0000000e+00\n'))
#                     label.append(int(content[0].rstrip('.0000000e+00\n')))
# print(a)
# X = np.zeros([293,490,640])
# y = np.zeros([293,],dtype = np.uint8)
# img_paths = []
# neutral_img_paths = []
# a = 0
# b = 0
# for file_name in label_file:
#     path_split = file_name.split('_')
#     img_path = "/Users/scott/Downloads/cohn-kanade-images/"+path_split[0]+"/"+path_split[1]+"/"+path_split[0]+"_"+path_split[1]+"_"+path_split[2]+".png"
#     neutral_img_path = "/Users/scott/Downloads/cohn-kanade-images/"+path_split[0]+"/"+path_split[1]+"/"+path_split[0]+"_"+path_split[1]+"_00000001.png"
#     #print(img_path)
#     #np.array(pixels,dtype=np.uint8)
#     img = io.imread(img_path)
#     if(img.shape == (490,640)):
#         #img = io.imread(img_path)
#         n_img = io.imread(neutral_img_path)
#         img_paths.append(img_path)
#         neutral_img_paths.append(neutral_img_path)
#         X[b,:,:]=img
#         y[b] = label[a]
#         cv2.imwrite("/Users/scott/Documents/FacialEmotion/sorted_set\\neutral\\%s.png" %(b), n_img)
#         cv2.imwrite("/Users/scott/Documents/FacialEmotion/sorted_set\\%s\\%s.png" %(emotions[label[a]], b), img)
#         b = b+1
#         #print(b)
#     a = a+1
#     #if(b==225):
#     #    break


# faceDet = cv2.CascadeClassifier("/Users/scott/Downloads/opencv-3.3.1/data/haarcascades/haarcascade_frontalface_default.xml")
# faceDet_two = cv2.CascadeClassifier("/Users/scott/Downloads/opencv-3.3.1/data/haarcascades/haarcascade_frontalface_alt2.xml")
# faceDet_three = cv2.CascadeClassifier("/Users/scott/Downloads/opencv-3.3.1/data/haarcascades/haarcascade_frontalface_alt.xml")
# faceDet_four = cv2.CascadeClassifier("/Users/scott/Downloads/opencv-3.3.1/data/haarcascades/haarcascade_frontalface_alt_tree.xml")
#  #Define emotions

# def detect_faces(emotion):
#     files = glob.glob("/Users/scott/Documents/FacialEmotion/sorted_set\\%s\\*" %emotion) 

#     filenumber = 0
#     total = 0
#     for f in files:
#         frame = cv2.imread(f) #Open image
#         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #Convert image to grayscale
        
#         #Detect face using 4 different classifiers
#         face = faceDet.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
#         face_two = faceDet_two.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
#         face_three = faceDet_three.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)
#         face_four = faceDet_four.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=10, minSize=(5, 5), flags=cv2.CASCADE_SCALE_IMAGE)

#         #Go over detected faces, stop at first detected face, return empty if no face.
#         if len(face) == 1:
#             facefeatures = face
#         elif len(face_two) == 1:
#             facefeatures = face_two
#         elif len(face_three) == 1:
#             facefeatures = face_three
#         elif len(face_four) == 1:
#             facefeatures = face_four
#         else:
#             facefeatures = ""
        
#         #Cut and save face
#         for (x, y, w, h) in facefeatures: #get coordinates and size of rectangle containing face
#             print "face found in file: %s" %f
#             gray = gray[y:y+h, x:x+w] #Cut the frame to size
            
#             try:
#                 out = cv2.resize(gray, (350, 350)) #
#                 cv2.imwrite("/Users/scott/Documents/FacialEmotion/dataset\\%s\\%s.jpg" %(emotion, filenumber), out) 
#             except:
#                pass 
#         filenumber += 1 #Increment image number

# for emotion in emotions: 
#     detect_faces(emotion) 



fishface = cv2.face.FisherFaceRecognizer_create() 

data = {}

def get_files(emotion):
    files = glob.glob("/Users/scott/Documents/FacialEmotion/dataset\\%s\\*" %emotion)
    random.shuffle(files)
    training = files#[:int(len(files)*0.8)] 
#     prediction = files[-int(len(files)*0.2):] 
    return training

def make_sets():
    training_data = []
    training_labels = []
    for emotion in emotions:
        training = get_files(emotion)
        for item in training:
            image = cv2.imread(item)
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            training_data.append(gray) 
            #print(gray.shape)
            #print(emotion)
            training_labels.append(emotions.index(emotion))
    
#         for item in prediction: 
#             image = cv2.imread(item)
#             gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#             prediction_data.append(gray)
#             prediction_labels.append(emotions.index(emotion))

    return training_data, training_labels#, prediction_data, prediction_labels

# def run_recognizer():
#     training_data, training_labels, prediction_data, prediction_labels = make_sets()
    
#     print "size of training set is:", len(training_labels), "images"
#     fishface.train(training_data, np.asarray(training_labels))

#     print "predicting classification set"
#     cur = 0
#     correct = 0
#     incorrect = 0
#     for image in prediction_data: 
#         pred, conf = fishface.predict(image)
#         if pred == prediction_labels[cur]:
#             correct += 1
#             cur += 1
#         else:
#             incorrect += 1
#             cur += 1
#     return ((100*correct)/(correct + incorrect))

# metascore = []
# for i in range(0,10):
#     correct = run_recognizer()
#     print "got", correct, "percent correct!"
#     metascore.append(correct)

# print "\n\nend score:", np.mean(metascore), "percent correct!"

# %%
training_data, training_labels = make_sets()

# %%
plt.imshow(training_data[2],cmap ="gray")
plt.show()
win = dlib.image_window()
win.set_image(training_data[2])
faces = faceCascade.detectMultiScale(  
       training_data[2],  
       scaleFactor=1.01,  
       minNeighbors=5,  
       minSize=(120, 120),  
       flags=cv2.CASCADE_SCALE_IMAGE  
    ) 
    #print("Found {0} faces!".format(len(faces))) 
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
print(x,y,w,h)
dlib_rect = dlib.rectangle(int(x), int(y), int(x + w), int(y + h)) 
shape = predictor(training_data[2], dlib_rect)
win.add_overlay(shape)
#print(training_labels)
# Out:
# (33, 29, 277, 277)

# %%
import csv
import numpy as np
import dlib
from skimage import io
import matplotlib.pyplot as plt
import cv2
import os  
import random
from sklearn import svm
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier

# %%
a = 0;
datasize = [4000,10000,20000]
datascale = datasize[2]
img = np.zeros([48,48,datascale])
label = np.zeros([datascale,],dtype=np.uint8)
n = 60
with open("/Users/scott/Downloads/fer2013/fer2013.csv") as csvfile:
    reader = [each for each in csv.DictReader(csvfile)]
for row in reader:
    #print(row["emotion"],row["pixels"])
    pixelstring = row["pixels"].split(" ")
    emotionstring = row["emotion"]
    emotion = int(emotionstring)
    pixels = map(int,pixelstring)
    #print(pixels)
    a += 1
    imgs = np.array(pixels,dtype=np.uint8)
    img[:,:,a-1]= np.resize(imgs,(48,48))
    label[a-1,] = emotion
    #plt.imshow(imgs.reshape(48,48),cmap='gray')
    #plt.show()
    if(a == img.shape[2]):
        break
for i in range(10):
    plt.imshow(img[:,:,n+i],cmap ="gray")
    plt.show()

# %%
print(len(training_data))
# Out:
# 562

# %%
predictor_path = "/Users/scott/Downloads/shape_predictor_68_face_landmarks.dat"
cascade_path = ["/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml",
                "/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_alt.xml",
                "/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_alt2.xml",
               "/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_alt_tree.xml"]
features = np.zeros([12,2,datascale])
labels = np.zeros([datascale,1])
faceCascade = cv2.CascadeClassifier(cascade_path[1])
predictor = dlib.shape_predictor(predictor_path)
recog_num = 0


training_data = np.array(training_data)
idx = np.random.permutation(len(training_data))
training_labels = np.array(training_labels)
training_data,training_labels = training_data[idx], training_labels[idx]

for i in range(len(training_data)):
    #image = io.imread("/Users/scott/Downloads/cohn-kanade-images/S005/001/S005_001_00000001.png")#np.array(pixels,dtype=np.uint8)
    image = np.array(training_data[i],dtype=np.uint8)
    #win = dlib.image_window()
    #win.set_image(image)
    faces = faceCascade.detectMultiScale(  
       image,  
       scaleFactor=1.1,  
       minNeighbors=5,  
       minSize=(20, 20),  
       flags=cv2.CASCADE_SCALE_IMAGE  
    ) 
    #print("Found {0} faces!".format(len(faces))) 
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    dlib_rect = dlib.rectangle(int(x), int(y), int(x + w), int(y + h)) 
    shape = predictor(image, dlib_rect)
    allshape = shape.parts()
    if (len(faces)==1):
        features[0,:,recog_num] = np.array([allshape[19].x-allshape[17].x,allshape[19].y-allshape[17].y])
        features[1,:,recog_num] = np.array([allshape[21].x-allshape[19].x,allshape[21].y-allshape[19].y])
        features[2,:,recog_num] = np.array([allshape[24].x-allshape[22].x,allshape[24].y-allshape[22].y])
        features[3,:,recog_num] = np.array([allshape[26].x-allshape[24].x,allshape[26].y-allshape[24].y])
        features[4,:,recog_num] = np.array([allshape[51].x-allshape[48].x,allshape[51].y-allshape[48].y])
        features[5,:,recog_num] = np.array([allshape[54].x-allshape[51].x,allshape[54].y-allshape[51].y])
        features[6,:,recog_num] = np.array([allshape[57].x-allshape[48].x,allshape[57].y-allshape[48].y])
        features[7,:,recog_num] = np.array([allshape[54].x-allshape[57].x,allshape[54].y-allshape[57].y])
        features[8,:,recog_num] = np.array([allshape[19].x-allshape[36].x,allshape[19].y-allshape[36].y])
        features[9,:,recog_num] = np.array([allshape[19].x-allshape[39].x,allshape[19].y-allshape[39].y])
        features[10,:,recog_num] = np.array([allshape[24].x-allshape[42].x,allshape[24].y-allshape[42].y])
        features[11,:,recog_num] = np.array([allshape[24].x-allshape[45].x,allshape[24].y-allshape[45].y])
        features[:,:,recog_num] = features[:,:,recog_num]/np.linalg.norm(features[:,:,recog_num])
        labels[recog_num,] = training_labels[i] 
        recog_num+=1
    #print(features[:,:,0])
    #print(allshape[51])
    #print(type(allshape[0].x))
    #win.add_overlay(shape)
print(recog_num)
training_data_raw = features[:,:,0:int(recog_num)]
training_label_raw = labels[0:int(recog_num),]
# predicting_data_raw = features[:,:,int(0.8*recog_num):recog_num]
# predicting_label_raw = labels[int(0.8*recog_num):recog_num,]
# training_data_raw = features[:,:,0:int(0.8*recog_num)]
# training_label_raw = labels[0:int(0.8*recog_num),]
# predicting_data_raw = features[:,:,int(0.8*recog_num):recog_num]
# predicting_label_raw = labels[int(0.8*recog_num):recog_num,]
training_data_process = np.reshape(training_data_raw,[24,-1]).T
training_label_process = np.array(training_label_raw,dtype = np.uint8)
print(training_data_process.shape)
# Out:
# 562
# (562, 24)

# %%
print(training_label_process[112])
# Out:
# [6]

# %%
predicting_data_process = np.reshape(predicting_data_raw,[24,-1]).T
predicting_label = np.array(predicting_label_raw.reshape(-1),dtype = np.uint8)

# %%
predictor_path = "/Users/scott/Downloads/shape_predictor_68_face_landmarks.dat"
cascade_path = ["/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml",
                "/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_alt.xml",
                "/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_alt2.xml",
               "/usr/local/Cellar/opencv/3.3.1_1/share/OpenCV/haarcascades/haarcascade_frontalface_alt_tree.xml"]
features = np.zeros([12,2,datascale])
labels = np.zeros([datascale,1])
faceCascade = cv2.CascadeClassifier(cascade_path[1])
predictor = dlib.shape_predictor(predictor_path)
recog_num = 0
for i in range(datascale):
    #image = io.imread("/Users/scott/Downloads/cohn-kanade-images/S005/001/S005_001_00000001.png")#np.array(pixels,dtype=np.uint8)
    image = np.array(img[:,:,i],dtype=np.uint8)
    #win = dlib.image_window()
    #win.set_image(image)
    faces = faceCascade.detectMultiScale(  
       image,  
       scaleFactor=1.1,  
       minNeighbors=1,  
       minSize=(20, 20),  
       flags=cv2.CASCADE_SCALE_IMAGE  
    ) 
    #print("Found {0} faces!".format(len(faces))) 
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    dlib_rect = dlib.rectangle(int(x), int(y), int(x + w), int(y + h)) 
    shape = predictor(image, dlib_rect)
    allshape = shape.parts()
    if (len(faces)==1):
        features[0,:,recog_num] = np.array([allshape[19].x-allshape[17].x,allshape[19].y-allshape[17].y])
        features[1,:,recog_num] = np.array([allshape[21].x-allshape[19].x,allshape[21].y-allshape[19].y])
        features[2,:,recog_num] = np.array([allshape[24].x-allshape[22].x,allshape[24].y-allshape[22].y])
        features[3,:,recog_num] = np.array([allshape[26].x-allshape[24].x,allshape[26].y-allshape[24].y])
        features[4,:,recog_num] = np.array([allshape[51].x-allshape[48].x,allshape[51].y-allshape[48].y])
        features[5,:,recog_num] = np.array([allshape[54].x-allshape[51].x,allshape[54].y-allshape[51].y])
        features[6,:,recog_num] = np.array([allshape[57].x-allshape[48].x,allshape[57].y-allshape[48].y])
        features[7,:,recog_num] = np.array([allshape[54].x-allshape[57].x,allshape[54].y-allshape[57].y])
        features[8,:,recog_num] = np.array([allshape[19].x-allshape[36].x,allshape[19].y-allshape[36].y])
        features[9,:,recog_num] = np.array([allshape[19].x-allshape[39].x,allshape[19].y-allshape[39].y])
        features[10,:,recog_num] = np.array([allshape[24].x-allshape[42].x,allshape[24].y-allshape[42].y])
        features[11,:,recog_num] = np.array([allshape[24].x-allshape[45].x,allshape[24].y-allshape[45].y])
        features[:,:,recog_num] = features[:,:,recog_num]/np.linalg.norm(features[:,:,recog_num])
        labels[recog_num,] = label[i,] 
        recog_num+=1
    #print(features[:,:,0])
    #print(allshape[51])
    #print(type(allshape[0].x))
    #win.add_overlay(shape)
print(recog_num)
#training_data_raw = features[:,:,0:int(0.8*recog_num)]
#training_label_raw = labels[0:int(0.8*recog_num),]
predicting_data_raw = features[:,:,0:int(recog_num)]
predicting_label_raw = labels[0:int(recog_num),]
predicting_data_process = np.reshape(predicting_data_raw,[24,-1]).T
predicting_label = np.array(predicting_label_raw.reshape(-1),dtype = np.uint8)
# Out:
# 12421

# %%
X = training_data_process
Y = training_label_process.reshape(-1)
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(100, 7), random_state=1)
clf.fit(X, Y)
print(X.shape)
# Out:
# (562, 24)

# %%
result = clf.predict(predicting_data_process)
result = np.array(result,dtype = np.uint8)
predicting_label = np.array(predicting_label_raw.reshape(-1),dtype = np.uint8)

num_correct=(np.sum(result==predicting_label))
accuracy = float(num_correct)/result.shape[0]
print('Got %d / %d correct => accuracy: %f' % (num_correct,result.shape[0],accuracy))
print(result)
print(predicting_label)
# Out:
# Got 4615 / 12421 correct => accuracy: 0.371548
# [0 6 0 ..., 6 2 6]
# [0 0 2 ..., 6 3 5]

# %%
com = np.zeros([7,7])
for i in range(len(result)):
    com[predicting_label[i],result[i]] +=1
print(np.sum(com,axis=1))
print(com)
print(com/np.sum(com,axis=1))
# Out:
# [ 1644.   195.  1696.  3327.  1628.  1499.  2432.]
# [[  562.   159.   122.    83.     0.   144.   574.]
#  [   65.    22.     8.    16.     0.    15.    69.]
#  [  342.    48.   169.   110.     0.   250.   777.]
#  [  219.    20.   692.  1719.     0.    74.   603.]
#  [  454.    47.    98.    76.     0.   119.   834.]
#  [  126.    24.   140.    62.     0.   642.   505.]
#  [  546.    50.    61.    81.     0.   193.  1501.]]
# [[ 0.34184915  0.81538462  0.07193396  0.0249474   0.          0.09606404
#    0.23601974]
#  [ 0.03953771  0.11282051  0.00471698  0.00480914  0.          0.01000667
#    0.02837171]
#  [ 0.2080292   0.24615385  0.09964623  0.03306282  0.          0.16677785
#    0.31949013]
#  [ 0.13321168  0.1025641   0.40801887  0.5166817   0.          0.04936624
#    0.24794408]
#  [ 0.27615572  0.24102564  0.05778302  0.0228434   0.          0.07938626
#    0.34292763]
#  [ 0.07664234  0.12307692  0.08254717  0.01863541  0.          0.42828552
#    0.20764803]
#  [ 0.33211679  0.25641026  0.03596698  0.02434626  0.          0.1287525
#    0.6171875 ]]
